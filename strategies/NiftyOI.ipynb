# %%
"""
NIFTY 31 JUL 2025 – OI profile (10-req/s batches)
Author  : OpenAlgo GPT
Updated : 2025-06-28
"""

print("🔁 OpenAlgo Python Bot is running.")                     # rule 13

import os, sys, re, time, asyncio, pandas as pd, plotly.graph_objects as go
from datetime import datetime
from openalgo import api

# ───────────── CONFIG (edit to suit) ─────────────────────────────────────
API_KEY  = os.getenv("OPENALGO_API_KEY",  "9c56d52753241db0345c2a8c576c0eea4d556523131b63c384b20f741c45f7f0")
API_HOST = os.getenv("OPENALGO_API_HOST", "http://127.0.0.1:5000")

EXPIRY        = "31JUL25"      # ✅ option expiry
RADIUS        = 20             # ± strikes
STEP          = 100            # ✅ 100-pt strikes (was 50)
BATCH_SIZE    = 10             # ✅ broker cap per second
BATCH_PAUSE   = 2           # seconds to wait between batches
MAX_RETRIES   = 1              # one retry on 429 / timeout
BACKOFF_SEC   = 1.2

client = api(api_key=API_KEY, host=API_HOST)
if sys.platform.startswith("win"):
    asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())

# ───────────── Helpers ───────────────────────────────────────────────────
def get_atm_strike(step: int = STEP) -> int:
    q = client.quotes(symbol="NIFTY", exchange="NSE_INDEX")
    print("Underlying Quote :", q)                               # rule 14
    return int(round(q["data"]["ltp"] / step) * step)

_sym_rx = re.compile(r"^[A-Z]+(\d{2}[A-Z]{3}\d{2})(\d+)(CE|PE)$")
def parse_symbol(sym: str):
    m = _sym_rx.match(sym)
    return (int(m.group(2)), m.group(3)) if m else None

def fetch_sync(sym: str) -> dict | None:
    """Blocking quote call with a retry for 429 / timeout."""
    for attempt in range(MAX_RETRIES + 1):
        q = client.quotes(symbol=sym, exchange="NFO")
        print(sym, "→", q)                                       # rule 14
        if q.get("status") == "success":
            strike, opt = parse_symbol(sym)
            if strike is None:
                print("⚠️  Bad symbol", sym)
                return None
            return dict(strike=strike, type=opt,
                        oi=q["data"]["oi"], ltp=q["data"]["ltp"])
        if (q.get("code") == 429 or q.get("error_type") == "timeout_error") and attempt < MAX_RETRIES:
            time.sleep(BACKOFF_SEC)
    return None

# ───────────── Batch-paced gather (≈5 req/s) ─────────────────────────────
async def gather_df() -> pd.DataFrame:
    atm = get_atm_strike()
    strikes = [atm + i*STEP for i in range(-RADIUS, RADIUS + 1)]
    symbols = [f"NIFTY{EXPIRY}{k}{s}" for k in strikes for s in ("CE", "PE")]

    rows: list[dict] = []
    for i in range(0, len(symbols), BATCH_SIZE):
        batch = symbols[i:i+BATCH_SIZE]
        res   = await asyncio.gather(*[asyncio.to_thread(fetch_sync, s) for s in batch])
        rows.extend(r for r in res if r)
        if i + BATCH_SIZE < len(symbols):
            await asyncio.sleep(BATCH_PAUSE)          # pace → 5 req/s

    if not rows:
        raise RuntimeError("All quotes failed – check API / symbols.")
    return pd.DataFrame(rows)

# ───────────── Plot (Call = green, Put = red, both positive) ─────────────
def plot_oi(df: pd.DataFrame):
    piv = (df.pivot(index="strike", columns="type", values=["oi", "ltp"])
             .sort_index())
    piv.columns = ["CE_OI", "PE_OI", "CE_LTP", "PE_LTP"]
    piv = piv.reset_index()

    fig = go.Figure()
    fig.add_bar(
        x=piv["strike"], y=piv["CE_OI"],          # no minus sign
        name="Call OI", marker_color="seagreen",  # ✅ green
        customdata=piv[["CE_OI", "CE_LTP"]],
        hovertemplate="<b>%{x} CE</b><br>OI %{customdata[0]:,}"
                      "<br>LTP ₹%{customdata[1]:.2f}<extra></extra>"
    )
    fig.add_bar(
        x=piv["strike"], y=piv["PE_OI"],
        name="Put OI", marker_color="crimson",    # ✅ red
        customdata=piv[["PE_OI", "PE_LTP"]],
        hovertemplate="<b>%{x} PE</b><br>OI %{customdata[0]:,}"
                      "<br>LTP ₹%{customdata[1]:.2f}<extra></extra>"
    )
    atm = get_atm_strike()
    fig.add_vline(
        x=piv.index[piv["strike"] == atm][0],
        line_dash="dash", line_color="gray",
        annotation_text=f"ATM {atm}", annotation_position="top"
    )
    fig.update_layout(
        title=f"NIFTY {datetime.strptime(EXPIRY,'%d%b%y').strftime('%d %b %Y')} – OI Profile",
        xaxis=dict(title="Strike", type="category"),
        yaxis_title="Open Interest",
        bargap=0.05, template="plotly_dark",
        height=500, width=1250,
        legend=dict(orientation="h", yanchor="bottom", y=1.02,
                    xanchor="right", x=1)
    )
    fig.show()

# ───────────── Runner (script / notebook) ────────────────────────────────
async def _main():
    df = await gather_df()
    print(df.head())
    plot_oi(df)

def _in_nb() -> bool:
    try:
        import IPython
        return IPython.get_ipython() is not None
    except ImportError:
        return False

if _in_nb():
    await _main()                   # Jupyter
else:
    asyncio.run(_main())            # script
# Out:
# 🔁 OpenAlgo Python Bot is running.
# Underlying Quote : {'data': {'ask': 0.0, 'bid': 0.0, 'high': 26041.7, 'low': 25839.85, 'ltp': 25888.8, 'oi': 0, 'open': 25939.95, 'prev_close': 25966.05, 'volume': 0}, 'status': 'success'}
# NIFTY31JUL2523900PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524000CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524300CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524200CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524000PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2523900CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524300PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524200PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524100PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524100CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524000CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2523900PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524200CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524000PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524200PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2523900CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524300CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524300PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524100CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524100PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524500PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524400CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524600CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524500CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524800CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524600PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524400PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524800PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524700PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524700CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524500PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524400CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524500CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524600CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524800CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524400PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524600PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524800PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524700CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524700PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524900PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525000PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524900CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525000CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525100PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525200PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525300CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525200CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525300PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525100CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524900PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525000PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525000CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2524900CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525200PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525100PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525300CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525200CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525300PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525100CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525400CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525500PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525500CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525700PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525400PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525600CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525800PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525600PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525800CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525700CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525400CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525500CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525500PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525400PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525800PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525700CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525600CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525800CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525700PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525600PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526000CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526000PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525900PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525900CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526100PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526300CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526300PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526200CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526200PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526100CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525900PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2525900CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526000CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526000PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526300CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526100PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526300PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526200PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526200CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526100CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526500PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526400PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526500CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526400CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526600CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526700CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526800CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526700PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526600PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526800PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526400PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526400CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526500PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526500CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526800CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526700CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526600CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526700PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526800PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526600PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526900PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526900CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527000PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527000CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527100CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527300PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527300CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527100PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527200PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527200CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526900PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527000PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527000CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2526900CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527100PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527300CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527300PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527200PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527200CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527100CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527400PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527500PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527500CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527700CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527400CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527800CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527800PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527600PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527600CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527700PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527500PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527500CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527400PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527400CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527600PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527700CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527600CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527800PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# NIFTY31JUL2527800CE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[5], line 127
#     124         return False
#     126 if _in_nb():
# --> 127     await _main()                   # Jupyter
#     128 else:
#     129     asyncio.run(_main())            # script
#
# Cell In[5], line 115, in _main()
#     114 async def _main():
# --> 115     df = await gather_df()
#     116     print(df.head())
#     117     plot_oi(df)
#
# Cell In[5], line 65, in gather_df()
#      63 for i in range(0, len(symbols), BATCH_SIZE):
#      64     batch = symbols[i:i+BATCH_SIZE]
# ---> 65     res   = await asyncio.gather(*[asyncio.to_thread(fetch_sync, s) for s in batch])
#      66     rows.extend(r for r in res if r)
#      67     if i + BATCH_SIZE < len(symbols):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# CancelledError:
# NIFTY31JUL2527700PE → {'status': 'error', 'message': 'HTTP 500: {"message":"Error fetching quotes: Error from Angel API: Invalid exchange tokens.","status":"error"}\n', 'code': 500, 'error_type': 'http_error'}
